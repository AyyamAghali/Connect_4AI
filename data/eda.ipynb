# %% [markdown]
# # Exploratory Data Analysis (EDA) for Connect 4 AI
#
# This notebook performs comprehensive exploratory data analysis on the collected Connect 4 game data.

# %% [markdown]
# ## 1. Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Load data
try:
    games_df = pd.read_csv('game_data.csv')
    moves_df = pd.read_csv('move_data.csv')
    print(f"Loaded {len(games_df)} games and {len(moves_df)} moves")
except FileNotFoundError:
    print("Data files not found. Please run data_collection.py first.")
    print("Loading sample data structure...")
    games_df = pd.DataFrame()
    moves_df = pd.DataFrame()
# Out:
# Running cells with '.conda (Python 3.11.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /Users/ayyamaghali/Connect_4AI/.conda ipykernel --update-deps --force-reinstall'
